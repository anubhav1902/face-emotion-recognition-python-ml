# %%
from keras.utils import to_categorical
from keras.preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
TRAIN_DIR = r'C:\Users\hp\Desktop\face detection\train'
TEST_DIR = r'C:\Users\hp\Desktop\face detection\test'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        path = os.path.join(dir, label)
        if not os.path.isdir(path):
            continue
        for image in os.listdir(path):
            image_paths.append(os.path.join(path, image))
            labels.append(label)
    return image_paths, labels

train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)

# %%
print(train)
# Out:
#                                                    image      label
# 0      C:\Users\hp\Desktop\face detection\train\angry...      angry
# 1      C:\Users\hp\Desktop\face detection\train\angry...      angry
# 2      C:\Users\hp\Desktop\face detection\train\angry...      angry
# 3      C:\Users\hp\Desktop\face detection\train\angry...      angry
# 4      C:\Users\hp\Desktop\face detection\train\angry...      angry
# ...                                                  ...        ...
# 28704  C:\Users\hp\Desktop\face detection\train\surpr...  surprised
# 28705  C:\Users\hp\Desktop\face detection\train\surpr...  surprised
# 28706  C:\Users\hp\Desktop\face detection\train\surpr...  surprised
# 28707  C:\Users\hp\Desktop\face detection\train\surpr...  surprised
# 28708  C:\Users\hp\Desktop\face detection\train\surpr...  surprised
#
# [28709 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)

# %%
print(test)
# Out:
#                                                   image      label
# 0     C:\Users\hp\Desktop\face detection\test\angry\...      angry
# 1     C:\Users\hp\Desktop\face detection\test\angry\...      angry
# 2     C:\Users\hp\Desktop\face detection\test\angry\...      angry
# 3     C:\Users\hp\Desktop\face detection\test\angry\...      angry
# 4     C:\Users\hp\Desktop\face detection\test\angry\...      angry
# ...                                                 ...        ...
# 7173  C:\Users\hp\Desktop\face detection\test\surpri...  surprised
# 7174  C:\Users\hp\Desktop\face detection\test\surpri...  surprised
# 7175  C:\Users\hp\Desktop\face detection\test\surpri...  surprised
# 7176  C:\Users\hp\Desktop\face detection\test\surpri...  surprised
# 7177  C:\Users\hp\Desktop\face detection\test\surpri...  surprised
#
# [7178 rows x 2 columns]

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image, color_mode='grayscale')
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28709 [00:00<?, ?it/s]

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7178 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
model = Sequential()

# ✅ First layer should be Input
model.add(Input(shape=(48, 48, 1)))  # Grayscale image

# Convolutional Layers
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

# Fully Connected Layers
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

# Output Layer
model.add(Dense(7, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x= x_train, y = y_train, epochs=100, batch_size=128, validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 185s 802ms/step - accuracy: 0.2377 - loss: 1.8361 - val_accuracy: 0.2471 - val_loss: 1.8160
# Epoch 2/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 642ms/step - accuracy: 0.2496 - loss: 1.8118 - val_accuracy: 0.2926 - val_loss: 1.7249
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 153s 681ms/step - accuracy: 0.2994 - loss: 1.7245 - val_accuracy: 0.3614 - val_loss: 1.6010
# Epoch 4/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 141s 627ms/step - accuracy: 0.3585 - loss: 1.6197 - val_accuracy: 0.4361 - val_loss: 1.4512
# Epoch 5/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 139s 618ms/step - accuracy: 0.4049 - loss: 1.5240 - val_accuracy: 0.4588 - val_loss: 1.4070
# Epoch 6/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 133s 592ms/step - accuracy: 0.4351 - loss: 1.4552 - val_accuracy: 0.4891 - val_loss: 1.3268
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 136s 603ms/step - accuracy: 0.4569 - loss: 1.4054 - val_accuracy: 0.5000 - val_loss: 1.2900
# Epoch 8/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 134s 593ms/step - accuracy: 0.4733 - loss: 1.3676 - val_accuracy: 0.5117 - val_loss: 1.2684
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 134s 593ms/step - accuracy: 0.4843 - loss: 1.3405 - val_accuracy: 0.5188 - val_loss: 1.2484
# Epoch 10/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 641ms/step - accuracy: 0.4968 - loss: 1.3083 - val_accuracy: 0.5276 - val_loss: 1.2246
# Epoch 11/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 636ms/step - accuracy: 0.5078 - loss: 1.2907 - val_accuracy: 0.5366 - val_loss: 1.1963
# Epoch 12/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 139s 618ms/step - accuracy: 0.5142 - loss: 1.2835 - val_accuracy: 0.5394 - val_loss: 1.2015
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 137s 609ms/step - accuracy: 0.5173 - loss: 1.2684 - val_accuracy: 0.5515 - val_loss: 1.1703
# Epoch 14/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 149s 661ms/step - accuracy: 0.5293 - loss: 1.2433 - val_accuracy: 0.5531 - val_loss: 1.1701
# Epoch 15/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 140s 624ms/step - accuracy: 0.5308 - loss: 1.2312 - val_accuracy: 0.5631 - val_loss: 1.1450
# Epoch 16/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 138s 615ms/step - accuracy: 0.5423 - loss: 1.2123 - val_accuracy: 0.5631 - val_loss: 1.1391
# Epoch 17/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 134s 597ms/step - accuracy: 0.5529 - loss: 1.1866 - val_accuracy: 0.5674 - val_loss: 1.1205
# Epoch 18/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 138s 614ms/step - accuracy: 0.5458 - loss: 1.2001 - val_accuracy: 0.5612 - val_loss: 1.1369
# Epoch 19/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 135s 601ms/step - accuracy: 0.5516 - loss: 1.1875 - val_accuracy: 0.5798 - val_loss: 1.1012
# Epoch 20/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 134s 596ms/step - accuracy: 0.5650 - loss: 1.1535 - val_accuracy: 0.5776 - val_loss: 1.1028
# Epoch 21/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 136s 605ms/step - accuracy: 0.5584 - loss: 1.1638 - val_accuracy: 0.5848 - val_loss: 1.0944
# Epoch 22/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 134s 593ms/step - accuracy: 0.5684 - loss: 1.1323 - val_accuracy: 0.5786 - val_loss: 1.1050
# Epoch 23/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 407s 2s/step - accuracy: 0.5673 - loss: 1.1376 - val_accuracy: 0.5889 - val_loss: 1.0792
# Epoch 24/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 129s 575ms/step - accuracy: 0.5717 - loss: 1.1287 - val_accuracy: 0.5938 - val_loss: 1.0712
# Epoch 25/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 134s 596ms/step - accuracy: 0.5820 - loss: 1.1127 - val_accuracy: 0.5908 - val_loss: 1.0769
# Epoch 26/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 134s 597ms/step - accuracy: 0.5758 - loss: 1.1164 - val_accuracy: 0.5958 - val_loss: 1.0710
# Epoch 27/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 135s 599ms/step - accuracy: 0.5843 - loss: 1.1026 - val_accuracy: 0.5964 - val_loss: 1.0742
# Epoch 28/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 137s 611ms/step - accuracy: 0.5845 - loss: 1.0992 - val_accuracy: 0.5901 - val_loss: 1.0801
# Epoch 29/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 135s 598ms/step - accuracy: 0.5827 - loss: 1.0991 - val_accuracy: 0.5931 - val_loss: 1.0672
# Epoch 30/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 134s 595ms/step - accuracy: 0.5909 - loss: 1.0863 - val_accuracy: 0.6046 - val_loss: 1.0580
# Epoch 31/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 134s 595ms/step - accuracy: 0.5904 - loss: 1.0812 - val_accuracy: 0.6002 - val_loss: 1.0518
# Epoch 32/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 152s 678ms/step - accuracy: 0.5955 - loss: 1.0692 - val_accuracy: 0.5965 - val_loss: 1.0624
# Epoch 33/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 761s 3s/step - accuracy: 0.6013 - loss: 1.0636 - val_accuracy: 0.5986 - val_loss: 1.0664
# Epoch 34/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 131s 582ms/step - accuracy: 0.6017 - loss: 1.0587 - val_accuracy: 0.6034 - val_loss: 1.0551
# Epoch 35/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 140s 621ms/step - accuracy: 0.6011 - loss: 1.0550 - val_accuracy: 0.6020 - val_loss: 1.0435
# Epoch 36/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 704ms/step - accuracy: 0.6061 - loss: 1.0374 - val_accuracy: 0.6050 - val_loss: 1.0514
# Epoch 37/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 159s 706ms/step - accuracy: 0.6101 - loss: 1.0364 - val_accuracy: 0.6095 - val_loss: 1.0348
# Epoch 38/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 704ms/step - accuracy: 0.6131 - loss: 1.0352 - val_accuracy: 0.6062 - val_loss: 1.0412
# Epoch 39/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 159s 706ms/step - accuracy: 0.6134 - loss: 1.0345 - val_accuracy: 0.6108 - val_loss: 1.0358
# Epoch 40/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 703ms/step - accuracy: 0.6186 - loss: 1.0105 - val_accuracy: 0.6035 - val_loss: 1.0443
# Epoch 41/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 155s 687ms/step - accuracy: 0.6204 - loss: 1.0121 - val_accuracy: 0.6117 - val_loss: 1.0421
# Epoch 42/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 158s 704ms/step - accuracy: 0.6210 - loss: 1.0226 - val_accuracy: 0.6119 - val_loss: 1.0402
# Epoch 43/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 240s 1s/step - accuracy: 0.6213 - loss: 1.0042 - val_accuracy: 0.6085 - val_loss: 1.0440
# Epoch 44/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 151s 671ms/step - accuracy: 0.6224 - loss: 1.0037 - val_accuracy: 0.6095 - val_loss: 1.0365
# Epoch 45/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 197s 877ms/step - accuracy: 0.6271 - loss: 0.9958 - val_accuracy: 0.6127 - val_loss: 1.0289
# Epoch 46/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 165s 734ms/step - accuracy: 0.6223 - loss: 0.9985 - val_accuracy: 0.6098 - val_loss: 1.0310
# Epoch 47/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 166s 738ms/step - accuracy: 0.6337 - loss: 0.9913 - val_accuracy: 0.6106 - val_loss: 1.0382
# Epoch 48/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 326s 1s/step - accuracy: 0.6367 - loss: 0.9825 - val_accuracy: 0.6077 - val_loss: 1.0300
# Epoch 49/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 372s 2s/step - accuracy: 0.6318 - loss: 0.9830 - val_accuracy: 0.6169 - val_loss: 1.0219
# Epoch 50/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 131s 583ms/step - accuracy: 0.6397 - loss: 0.9692 - val_accuracy: 0.6163 - val_loss: 1.0316
# Epoch 51/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 578s 3s/step - accuracy: 0.6421 - loss: 0.9652 - val_accuracy: 0.6106 - val_loss: 1.0212
# Epoch 52/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.6408 - loss: 0.9601 - val_accuracy: 0.6121 - val_loss: 1.0310
# Epoch 53/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1057s 5s/step - accuracy: 0.6455 - loss: 0.9543 - val_accuracy: 0.6206 - val_loss: 1.0193
# Epoch 54/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1051s 5s/step - accuracy: 0.6440 - loss: 0.9549 - val_accuracy: 0.6199 - val_loss: 1.0216
# Epoch 55/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 6778s 30s/step - accuracy: 0.6483 - loss: 0.9496 - val_accuracy: 0.6159 - val_loss: 1.0175
# Epoch 56/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 815s 4s/step - accuracy: 0.6548 - loss: 0.9370 - val_accuracy: 0.6173 - val_loss: 1.0146
# Epoch 57/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 923s 4s/step - accuracy: 0.6524 - loss: 0.9203 - val_accuracy: 0.6174 - val_loss: 1.0220
# Epoch 58/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 903s 4s/step - accuracy: 0.6538 - loss: 0.9248 - val_accuracy: 0.6174 - val_loss: 1.0223
# Epoch 59/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 139s 620ms/step - accuracy: 0.6466 - loss: 0.9419 - val_accuracy: 0.6206 - val_loss: 1.0121
# Epoch 60/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 139s 616ms/step - accuracy: 0.6539 - loss: 0.9249 - val_accuracy: 0.6183 - val_loss: 1.0178
# Epoch 61/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 639ms/step - accuracy: 0.6664 - loss: 0.9063 - val_accuracy: 0.6193 - val_loss: 1.0176
# Epoch 62/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 639ms/step - accuracy: 0.6639 - loss: 0.9093 - val_accuracy: 0.6223 - val_loss: 1.0242
# Epoch 63/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 142s 632ms/step - accuracy: 0.6609 - loss: 0.9157 - val_accuracy: 0.6169 - val_loss: 1.0215
# Epoch 64/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 140s 623ms/step - accuracy: 0.6615 - loss: 0.9037 - val_accuracy: 0.6202 - val_loss: 1.0238
# Epoch 65/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 636ms/step - accuracy: 0.6699 - loss: 0.8896 - val_accuracy: 0.6209 - val_loss: 1.0278
# Epoch 66/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 634ms/step - accuracy: 0.6688 - loss: 0.8958 - val_accuracy: 0.6163 - val_loss: 1.0210
# Epoch 67/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 145s 644ms/step - accuracy: 0.6709 - loss: 0.8915 - val_accuracy: 0.6243 - val_loss: 1.0127
# Epoch 68/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 637ms/step - accuracy: 0.6726 - loss: 0.8818 - val_accuracy: 0.6259 - val_loss: 1.0173
# Epoch 69/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 145s 644ms/step - accuracy: 0.6728 - loss: 0.8771 - val_accuracy: 0.6206 - val_loss: 1.0228
# Epoch 70/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 636ms/step - accuracy: 0.6785 - loss: 0.8645 - val_accuracy: 0.6211 - val_loss: 1.0146
# Epoch 71/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 147s 652ms/step - accuracy: 0.6808 - loss: 0.8635 - val_accuracy: 0.6202 - val_loss: 1.0178
# Epoch 72/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 141s 628ms/step - accuracy: 0.6756 - loss: 0.8720 - val_accuracy: 0.6254 - val_loss: 1.0213
# Epoch 73/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 637ms/step - accuracy: 0.6829 - loss: 0.8591 - val_accuracy: 0.6269 - val_loss: 1.0169
# Epoch 74/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 141s 627ms/step - accuracy: 0.6827 - loss: 0.8634 - val_accuracy: 0.6269 - val_loss: 1.0156
# Epoch 75/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 141s 625ms/step - accuracy: 0.6871 - loss: 0.8474 - val_accuracy: 0.6282 - val_loss: 1.0160
# Epoch 76/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 641ms/step - accuracy: 0.6840 - loss: 0.8525 - val_accuracy: 0.6255 - val_loss: 1.0155
# Epoch 77/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 634ms/step - accuracy: 0.6890 - loss: 0.8438 - val_accuracy: 0.6266 - val_loss: 1.0140
# Epoch 78/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 642ms/step - accuracy: 0.6902 - loss: 0.8378 - val_accuracy: 0.6251 - val_loss: 1.0208
# Epoch 79/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 637ms/step - accuracy: 0.6827 - loss: 0.8481 - val_accuracy: 0.6287 - val_loss: 1.0117
# Epoch 80/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 146s 647ms/step - accuracy: 0.6929 - loss: 0.8292 - val_accuracy: 0.6269 - val_loss: 1.0149
# Epoch 81/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 640ms/step - accuracy: 0.6966 - loss: 0.8213 - val_accuracy: 0.6293 - val_loss: 1.0187
# Epoch 82/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 635ms/step - accuracy: 0.7000 - loss: 0.8078 - val_accuracy: 0.6195 - val_loss: 1.0270
# Epoch 83/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 145s 643ms/step - accuracy: 0.7023 - loss: 0.8155 - val_accuracy: 0.6303 - val_loss: 1.0078
# Epoch 84/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 641ms/step - accuracy: 0.7009 - loss: 0.8071 - val_accuracy: 0.6317 - val_loss: 1.0108
# Epoch 85/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 641ms/step - accuracy: 0.7053 - loss: 0.8050 - val_accuracy: 0.6308 - val_loss: 1.0079
# Epoch 86/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 142s 632ms/step - accuracy: 0.7020 - loss: 0.7973 - val_accuracy: 0.6269 - val_loss: 1.0198
# Epoch 87/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 641ms/step - accuracy: 0.7057 - loss: 0.8101 - val_accuracy: 0.6279 - val_loss: 1.0149
# Epoch 88/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 145s 646ms/step - accuracy: 0.7013 - loss: 0.8117 - val_accuracy: 0.6322 - val_loss: 1.0117
# Epoch 89/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 640ms/step - accuracy: 0.7151 - loss: 0.7851 - val_accuracy: 0.6301 - val_loss: 1.0217
# Epoch 90/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 146s 651ms/step - accuracy: 0.7128 - loss: 0.7886 - val_accuracy: 0.6254 - val_loss: 1.0185
# Epoch 91/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 145s 643ms/step - accuracy: 0.7139 - loss: 0.7880 - val_accuracy: 0.6239 - val_loss: 1.0261
# Epoch 92/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 145s 643ms/step - accuracy: 0.7118 - loss: 0.7969 - val_accuracy: 0.6310 - val_loss: 1.0204
# Epoch 93/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 145s 644ms/step - accuracy: 0.7148 - loss: 0.7726 - val_accuracy: 0.6278 - val_loss: 1.0253
# Epoch 94/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 145s 645ms/step - accuracy: 0.7167 - loss: 0.7757 - val_accuracy: 0.6305 - val_loss: 1.0101
# Epoch 95/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 143s 636ms/step - accuracy: 0.7233 - loss: 0.7644 - val_accuracy: 0.6344 - val_loss: 1.0176
# Epoch 96/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 145s 642ms/step - accuracy: 0.7249 - loss: 0.7542 - val_accuracy: 0.6381 - val_loss: 1.0121
# Epoch 97/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 146s 648ms/step - accuracy: 0.7274 - loss: 0.7499 - val_accuracy: 0.6339 - val_loss: 1.0194
# Epoch 98/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 144s 638ms/step - accuracy: 0.7244 - loss: 0.7541 - val_accuracy: 0.6362 - val_loss: 1.0362
# Epoch 99/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 140s 623ms/step - accuracy: 0.7281 - loss: 0.7597 - val_accuracy: 0.6328 - val_loss: 1.0076
# Epoch 100/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 140s 623ms/step - accuracy: 0.7247 - loss: 0.7522 - val_accuracy: 0.6349 - val_loss: 1.0175

# %%
model_json = model.to_json()
with open("face detection.json",'w') as json_file:
    json_file.write(model_json)
model.save("face_detection.keras")

# %%
from keras.models import model_from_json

# %%
json_file = open("face detection.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("face detection.h5")

# %%
label = ['angry','disgust','fearful','happy','neutral','sad','surprise']

# %%
from tensorflow.keras.utils import load_img, img_to_array

def ef(image):
    img = load_img(image, color_mode='grayscale', target_size=(48, 48))  # load image in grayscale
    img = img_to_array(img)  # convert to array
    img = img.reshape(1, 48, 48, 1)  # reshape for model input
    img = img / 255.0  # normalize
    return img

# %%
image = r"C:\Users\hp\Desktop\face detection\train\sad\im55.png"
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is",pred_label)
# Out:
# original image is of angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# model prediction is sad

# %%
import matplotlib.pyplot as plt  

# %matplotlib inline

# %%
image = r"C:\Users\hp\Desktop\face detection\train\angry\im22.png"
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
img_display = load_img(image, color_mode='grayscale')
plt.imshow(img_display, cmap='gray')
plt.axis('off')
plt.title(f"Predicted Emotion: {pred_label}")
plt.show()
# Out:
# original image is of angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
image = r"C:\Users\hp\Desktop\face detection\train\sad\im22.png"
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
img_display = load_img(image, color_mode='grayscale')
plt.imshow(img_display, cmap='gray')
plt.axis('off')
plt.title(f"Predicted Emotion: {pred_label}")
plt.show()
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
image = r"C:\Users\hp\Desktop\face detection\train\neutral\im22.png"
print("original image is of neutral")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
img_display = load_img(image, color_mode='grayscale')
plt.imshow(img_display, cmap='gray')
plt.axis('off')
plt.title(f"Predicted Emotion: {pred_label}")
plt.show()
# Out:
# original image is of neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
image = r"C:\Users\hp\Desktop\face detection\train\surprised\im22.png"
print("original image is of surprised")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
img_display = load_img(image, color_mode='grayscale')
plt.imshow(img_display, cmap='gray')
plt.axis('off')
plt.title(f"Predicted Emotion: {pred_label}")
plt.show()
# Out:
# original image is of surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
image = r"C:\Users\hp\Desktop\face detection\train\happy\im22.png"
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
img_display = load_img(image, color_mode='grayscale')
plt.imshow(img_display, cmap='gray')
plt.axis('off')
plt.title(f"Predicted Emotion: {pred_label}")
plt.show()
# Out:
# original image is of happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
